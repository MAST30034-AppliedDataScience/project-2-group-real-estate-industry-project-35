# %%
import pandas as pd
import geojson
from geojson import Feature, Point, FeatureCollection

# Read the school CSV file
market_df = pd.read_csv('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\\VIC_School_Location.csv', encoding='ISO-8859-1')
market_df = market_df.dropna(subset=['X', 'Y'])

# Function to create GeoJSON Features
def create_geojson_feature(row, feature_type='house'):
    point = Point((row['X'], row['Y']))
    properties = {
        'address': row.get('address', 'unknown'),  # Modify the 'address' column as needed
        'type': feature_type
    }
    return Feature(geometry=point, properties=properties)

# Convert school data to GeoJSON Features
gym_features = market_df.apply(lambda row: create_geojson_feature(row, 'school'), axis=1).tolist()
gym_feature_collection = FeatureCollection(gym_features)

# Save schools as a GeoJSON file
houses_geojson_output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\schools_geojson.geojson'

with open(houses_geojson_output_path, 'w') as f:
    geojson.dump(gym_feature_collection, f)

print("GeoJSON file for schools has been generated")

# %%
import os
import pandas as pd
import numpy as np

# Read the CSV file
file_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\property_addresses_to_lat_lng.csv'
data = pd.read_csv(file_path)

# Split the data into 4 parts
split_data = np.array_split(data, 4)

# Specify the destination folder to save the files
destination_folder = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property'  # Specify the path where you want to save the files

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Save each part into separate files
for i, chunk in enumerate(split_data):
    chunk_file_path = os.path.join(destination_folder, f'part_{i+1}.csv')
    chunk.to_csv(chunk_file_path, index=False)

print(f"The file has been successfully split into 4 parts and saved to {destination_folder}.")

# %%
import pandas as pd
import geojson
from geojson import Feature, Point, FeatureCollection

# Read the CSV file
market_df = pd.read_csv('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part_1.csv')
market_df = market_df.dropna(subset=['longitude', 'latitude'])

# Function to create GeoJSON Features
def create_geojson_feature(row, feature_type='house'):
    point = Point((row['longitude'], row['latitude']))
    properties = {
        'address': row.get('address', 'unknown'),  # Modify the 'address' column as needed
        'type': feature_type
    }
    return Feature(geometry=point, properties=properties)

# Convert data to GeoJSON Features
gym_features = market_df.apply(lambda row: create_geojson_feature(row, 'house'), axis=1).tolist()
gym_feature_collection = FeatureCollection(gym_features)

# Save the data as a GeoJSON file
houses_geojson_output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part1_geojson.geojson'

with open(houses_geojson_output_path, 'w') as f:
    geojson.dump(gym_feature_collection, f)

print("The GeoJSON file for part 1 has been generated")

# %%
import pandas as pd
import geojson
from geojson import Feature, Point, FeatureCollection

# Read the CSV file
market_df = pd.read_csv('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part_2.csv')
market_df = market_df.dropna(subset=['longitude', 'latitude'])

# Function to create GeoJSON Features
def create_geojson_feature(row, feature_type='house'):
    point = Point((row['longitude'], row['latitude']))
    properties = {
        'address': row.get('address', 'unknown'),  # Modify the 'address' column as needed
        'type': feature_type
    }
    return Feature(geometry=point, properties=properties)

# Convert data to GeoJSON Features
gym_features = market_df.apply(lambda row: create_geojson_feature(row, 'house'), axis=1).tolist()
gym_feature_collection = FeatureCollection(gym_features)

# Save the data as a GeoJSON file
houses_geojson_output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part2_geojson.geojson'

with open(houses_geojson_output_path, 'w') as f:
    geojson.dump(gym_feature_collection, f)

print("The GeoJSON file for part 2 has been generated")

# %%
import pandas as pd
import geojson
from geojson import Feature, Point, FeatureCollection

# Read the CSV file
market_df = pd.read_csv('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part_3.csv')
market_df = market_df.dropna(subset=['longitude', 'latitude'])

# Function to create GeoJSON Features
def create_geojson_feature(row, feature_type='house'):
    point = Point((row['longitude'], row['latitude']))
    properties = {
        'address': row.get('address', 'unknown'),  # Modify the 'address' column as needed
        'type': feature_type
    }
    return Feature(geometry=point, properties=properties)

# Convert data to GeoJSON Features
gym_features = market_df.apply(lambda row: create_geojson_feature(row, 'house'), axis=1).tolist()
gym_feature_collection = FeatureCollection(gym_features)

# Save the data as a GeoJSON file
houses_geojson_output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part3_geojson.geojson'

with open(houses_geojson_output_path, 'w') as f:
    geojson.dump(gym_feature_collection, f)

print("The GeoJSON file for part 3 has been generated")

# %%
import geojson
import openrouteservice
import pandas as pd
import time

api_key = '5b3ce3597851110001cf62483b1a72a766444e06858b2f513c1a4ac6'
client = openrouteservice.Client(key=api_key)

with open('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part1_geojson.geojson', 'r') as f:
    rent_geojson = geojson.load(f)

with open('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\schools_geojson.geojson', 'r') as f:
    school_geojson = geojson.load(f)

def extract_coordinates(features):
    coordinates = []
    for feature in features['features']:
        lon, lat = feature['geometry']['coordinates']
        address = feature['properties'].get('address', 'unknown')
        coordinates.append((lat, lon, address))
    return coordinates

rent_coordinates = extract_coordinates(rent_geojson)
school_coordinates = extract_coordinates(school_geojson)

house_coords = [(lon, lat) for lat, lon, _ in rent_coordinates]
school_coords = [(lon, lat) for lat, lon, _ in school_coordinates]

def calculate_distance_matrix_in_batches(house_coords, school_coords, batch_size=1):
    all_shortest_distances = []
    
    for i in range(0, len(house_coords), batch_size):
        batch_houses = house_coords[i:i + batch_size]
        try:
            matrix = client.distance_matrix(
                locations=batch_houses + school_coords,
                profile='driving-car',
                sources=list(range(len(batch_houses))),
                destinations=list(range(len(batch_houses), len(batch_houses) + len(school_coords))),
                metrics=['distance'],
                units='km'
            )
            distances = matrix['distances']
            
            for j, house_distances in enumerate(distances[:len(batch_houses)]):
                valid_distances = [d for d in house_distances if d is not None]
                if valid_distances:
                    min_distance = min(valid_distances)
                    closest_school_idx = house_distances.index(min_distance)
                    rent_address = rent_coordinates[i + j][2]
                    closest_school = school_coordinates[closest_school_idx][2]
                    all_shortest_distances.append({
                        'rent_address': rent_address,
                        'closest_school': closest_school,
                        'min_driving_distance_km': min_distance
                    })
        except Exception as e:
            print(f"Error calculating distance matrix: {e}")
        time.sleep(1)
    
    return all_shortest_distances

shortest_distances = calculate_distance_matrix_in_batches(house_coords, school_coords, batch_size=1)

shortest_distances_df = pd.DataFrame(shortest_distances)
output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\closest_school_distance_part_1.csv'
shortest_distances_df.to_csv(output_path, index=False)

print(f"saved {output_path}")

# %%
import geojson
import openrouteservice
import pandas as pd
import time

api_key = '5b3ce3597851110001cf6248932b1acdd31d4250b8ae5c18277e8cad' 

with open('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part2_geojson.geojson', 'r') as f:
    rent_geojson = geojson.load(f)

with open('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\schools_geojson.geojson', 'r') as f:
    school_geojson = geojson.load(f)

def extract_coordinates(features):
    coordinates = []
    for feature in features['features']:
        lon, lat = feature['geometry']['coordinates']
        address = feature['properties'].get('address', 'unknown')
        coordinates.append((lat, lon, address))
    return coordinates

rent_coordinates = extract_coordinates(rent_geojson)
school_coordinates = extract_coordinates(school_geojson)

house_coords = [(lon, lat) for lat, lon, _ in rent_coordinates]
school_coords = [(lon, lat) for lat, lon, _ in school_coordinates]

def calculate_distance_matrix_in_batches(house_coords, school_coords, batch_size=1):
    all_shortest_distances = []
    
    for i in range(0, len(house_coords), batch_size):
        batch_houses = house_coords[i:i + batch_size]
        try:
            matrix = client.distance_matrix(
                locations=batch_houses + school_coords,
                profile='driving-car',
                sources=list(range(len(batch_houses))),
                destinations=list(range(len(batch_houses), len(batch_houses) + len(school_coords))),
                metrics=['distance'],
                units='km'
            )
            distances = matrix['distances']
            
            for j, house_distances in enumerate(distances[:len(batch_houses)]):
                valid_distances = [d for d in house_distances if d is not None]
                if valid_distances:
                    min_distance = min(valid_distances)
                    closest_school_idx = house_distances.index(min_distance)
                    rent_address = rent_coordinates[i + j][2]
                    closest_school = school_coordinates[closest_school_idx][2]
                    all_shortest_distances.append({
                        'rent_address': rent_address,
                        'closest_school': closest_school,
                        'min_driving_distance_km': min_distance
                    })
        except Exception as e:
            print(f"Error calculating distance matrix: {e}")
        time.sleep(1)
    
    return all_shortest_distances

shortest_distances = calculate_distance_matrix_in_batches(house_coords, school_coords, batch_size=1)

shortest_distances_df = pd.DataFrame(shortest_distances)
output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\closest_school_distance_part_2.csv'
shortest_distances_df.to_csv(output_path, index=False)

print(f"saved {output_path}")

# %%
import geojson
import openrouteservice
import pandas as pd
import time

api_key = '5b3ce3597851110001cf6248932b1acdd31d4250b8ae5c18277e8cad' 
client = openrouteservice.Client(key=api_key)

with open('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part3_geojson.geojson', 'r') as f:
    rent_geojson = geojson.load(f)

with open('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\schools_geojson.geojson', 'r') as f:
    school_geojson = geojson.load(f)

def extract_coordinates(features):
    coordinates = []
    for feature in features['features']:
        lon, lat = feature['geometry']['coordinates']
        address = feature['properties'].get('address', 'unknown')
        coordinates.append((lat, lon, address))
    return coordinates

rent_coordinates = extract_coordinates(rent_geojson)
school_coordinates = extract_coordinates(school_geojson)

house_coords = [(lon, lat) for lat, lon, _ in rent_coordinates]
school_coords = [(lon, lat) for lat, lon, _ in school_coordinates]

def calculate_distance_matrix_in_batches(house_coords, school_coords, batch_size=1):
    all_shortest_distances = []
    
    for i in range(0, len(house_coords), batch_size):
        batch_houses = house_coords[i:i + batch_size]
        try:
            matrix = client.distance_matrix(
                locations=batch_houses + school_coords,
                profile='driving-car',
                sources=list(range(len(batch_houses))),
                destinations=list(range(len(batch_houses), len(batch_houses) + len(school_coords))),
                metrics=['distance'],
                units='km'
            )
            distances = matrix['distances']
            
            for j, house_distances in enumerate(distances[:len(batch_houses)]):

                valid_distances = [d for d in house_distances if d is not None]
                if valid_distances:
                    min_distance = min(valid_distances)
                    closest_school_idx = house_distances.index(min_distance)
                    rent_address = rent_coordinates[i + j][2]
                    closest_school = school_coordinates[closest_school_idx][2]
                    all_shortest_distances.append({
                        'rent_address': rent_address,
                        'closest_school': closest_school,
                        'min_driving_distance_km': min_distance
                    })
        except Exception as e:
            print(f"Error calculating distance matrix: {e}")
        time.sleep(1)
    
    return all_shortest_distances

shortest_distances = calculate_distance_matrix_in_batches(house_coords, school_coords, batch_size=1)

shortest_distances_df = pd.DataFrame(shortest_distances)
output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\closest_school_distance_part_3.csv'
shortest_distances_df.to_csv(output_path, index=False)

print(f"saved {output_path}")

# %%
import pandas as pd
import geojson
from geojson import Feature, Point, FeatureCollection

market_df = pd.read_csv('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part_4.csv')
market_df = market_df.dropna(subset=['longitude', 'latitude'])


def create_geojson_feature(row, feature_type='house'):
    point = Point((row['longitude'], row['latitude']))
    properties = {
        'address': row.get('address', 'unknown'),
        'type': feature_type
    }
    return Feature(geometry=point, properties=properties)

gym_features = market_df.apply(lambda row: create_geojson_feature(row, 'house'), axis=1).tolist()
gym_feature_collection = FeatureCollection(gym_features)


houses_geojson_output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\part4_geojson.geojson'

with open(houses_geojson_output_path, 'w') as f:
    geojson.dump(gym_feature_collection, f)


print("part4")

# %%
import geojson
import openrouteservice
import pandas as pd
import time

api_key = '5b3ce3597851110001cf6248dda07331ae64496fa25c4e54b59fba30' 
client = openrouteservice.Client(key=api_key)

with open('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\curated\property\part4_geojson.geojson', 'r') as f:
    rent_geojson = geojson.load(f)

with open('D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\schools_geojson.geojson', 'r') as f:
    school_geojson = geojson.load(f)

def extract_coordinates(features):
    coordinates = []
    for feature in features['features']:
        lon, lat = feature['geometry']['coordinates']
        address = feature['properties'].get('address', 'unknown')
        coordinates.append((lat, lon, address))
    return coordinates

rent_coordinates = extract_coordinates(rent_geojson)
school_coordinates = extract_coordinates(school_geojson)

house_coords = [(lon, lat) for lat, lon, _ in rent_coordinates]
school_coords = [(lon, lat) for lat, lon, _ in school_coordinates]

def calculate_distance_matrix_in_batches(house_coords, school_coords, batch_size=1):
    all_shortest_distances = []
    
    for i in range(0, len(house_coords), batch_size):
        batch_houses = house_coords[i:i + batch_size]
        try:
            matrix = client.distance_matrix(
                locations=batch_houses + school_coords,
                profile='driving-car',
                sources=list(range(len(batch_houses))),
                destinations=list(range(len(batch_houses), len(batch_houses) + len(school_coords))),
                metrics=['distance'],
                units='km'
            )
            distances = matrix['distances']
            
            for j, house_distances in enumerate(distances[:len(batch_houses)]):
                valid_distances = [d for d in house_distances if d is not None]
                if valid_distances:
                    min_distance = min(valid_distances)
                    closest_school_idx = house_distances.index(min_distance)
                    rent_address = rent_coordinates[i + j][2]
                    closest_school = school_coordinates[closest_school_idx][2]
                    all_shortest_distances.append({
                        'rent_address': rent_address,
                        'closest_school': closest_school,
                        'min_driving_distance_km': min_distance
                    })
        except Exception as e:
            print(f"Error calculating distance matrix: {e}")
        time.sleep(1)
    
    return all_shortest_distances

shortest_distances = calculate_distance_matrix_in_batches(house_coords, school_coords, batch_size=1)

shortest_distances_df = pd.DataFrame(shortest_distances)
output_path = 'D:\STUDYfile\\ads2\\111ads\project-2-group-real-estate-industry-project-35\data\\raw\external\API\\1\\closest_school_distance_part_4.csv'
shortest_distances_df.to_csv(output_path, index=False)

print(f"saved {output_path}")
